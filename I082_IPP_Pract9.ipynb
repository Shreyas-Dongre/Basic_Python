# %% [markdown]
# #Practical 9
#
# Name: Shreyas Dongre
# Roll no: 082
# Division: I
# Semester: 2nd Semester
# Batch: I3
# Experiment 9 - To study strings in Python.
# Date of Experiment: 29/4/2021

# %% [markdown]
# #Task 1
# Write a program  to convert camel case string to snake case.
# Input: IntroductionToPythonProgramming
# Output:introduction_to_python_programming

# %%
import string
letters = set(string.ascii_uppercase)
a = input('Enter String: ')
b = [a[0].lower()]
for c in a[1:]:
  if c in letters:
    b.append('_')
    b.append(c.lower())
  else :
    b.append(c)

d = ''.join(b)
print('Output:',d)
# Out:
# Enter String: IntroductionToPythonProgramming
# Output: introduction_to_python_programming

# %% [markdown]
# #Task 2
# Write a program to delete consonants from the string and print the new string.
# Input: Python Programming
# Output: o oai

# %%
a = input('Enter String: ')
b = []

for i in a:
  if i in "aeiouAEIOU ":
    b.extend(i)
b = "".join(b)    
print('Output:',b)
# Out:
# Enter String: Python Programming
# Output: o oai

# %% [markdown]
# #Task 3
# 1.	Write a program to convert  numbers to numeric words.
# Input: 54320
# Output: five four three two zero
# 2.	Write a program to convert numeric words to numbers.
# Input: five four three two zero
# Output: 5 4 3 2 0

# %%
#3.1
a = input('Enter Number: ')
words = {'0': 'zero', '1': 'one', '2': 'two', '3': 'three', '4': 'four', '5': 'five', '6': 'six', '7': 'seven', '8': 'eight', '9': 'nine'}
b = " ".join(map(lambda x: words[x], str(a)))
print('Output:',b)
# Out:
# Enter Number: 54320
# Output: five four three two zero

# %%
#3.2
a = input('Enter Numeric Words: ')
words = {'zero': '0', 'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5', 'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'}
b = " ".join(words[i] for i in a.split())
print('Output:',b)
# Out:
# Enter Numeric Words: five four three two zero
# Output: 5 4 3 2 0

# %% [markdown]
# #Task 4
# Write a Python program to remove punctuation from a user given string.
# Input: Oh God! It's so hot in here!
# Output: Oh God Its so hot in here

# %%
a = input('Enter String: ')
b = '''!()-[]{},;:""''\?/<>.@#$%^&*()_=~'''
c = ""
for i in a:
  if i not in b:
    c +=i
print('Output:',c)
# Out:
# Enter String: Oh God! It's so hot in here!
# Output: Oh God Its so hot in here

# %% [markdown]
# #Task 5
# Write a Python program to remove a character at ‘k’ th index and print the string.
# Input: Hello! Goood Morning, k=8
# Output: Hello! Good Morning

# %%
a = input('Enter String: ')
b = int(input('Enter the index of the char to Delete: '))
c = ''
for i in range(0,len(a)):
  if (i != b):
    c += a[i]
print('Output:',c)
# Out:
# Enter String: Hello! Goood Morning
# Enter the index of the char to Delete: 8
# Output: Hello! Good Morning

# %% [markdown]
# #Task 6
# Write a Python to  arrange string characters such that all lowercase letters should be printed first.
# Input: ABCDefghIGKLmnopQRSTuvwxYZ
# Output: efghmnopuvwxABCDIGKLQRSTYZ

# %%
a = input('Enter String: ')
l = []
u = []
for i in a:
  if i.islower():
    l.append(i)
  else:
    u.append(i)
res = ''.join(l + u)
print('Output:',res)
# Out:
# Enter String: ABCDefghIGKLmnopQRSTuvwxYZ
# Output: efghmnopuvwxABCDIGKLQRSTYZ

# %% [markdown]
# #Task 7
# Write a Python Program to create a mixed String using the s1 and s2.
# Print first char of s1 then the last char of s2,    Next, the second char of s1 and second last char of s2, and so on.                                                                          Any leftover characters should be printed at the last.
#
# ![ipppract9table.JPG](data:image/jpeg;base64,...)

# %%
z = int(input('Enter number of Test Cases: '))
for i in range (0,z):
  a = input('Enter String 1: ')
  b = input('Enter String 2: ')
  b = b[::-1]
  la = len(a)
  lb = len(b)
  l = la if la>lb else lb
  res = ''
  for i in range(l):
    if (i<la):
      res += a[i]
    if (i<lb):
      res += b[i]  
  print('Output:',res)
# Out:
# Enter number of Test Cases: 3
# Enter String 1: abcd
# Enter String 2: wxyzef
# Output: afbeczdyxw
# Enter String 1: abcd
# Enter String 2: wxyz
# Output: azbycxdw
# Enter String 1: abcdef
# Enter String 2: wxyz
# Output: azbycxdwef

# %% [markdown]
# #Conclusion
# 1) Operated on strings using append(),join(),upper(),lower() to append two strings,join two or more strings, to convert string to uppercase, to convert string to lowercase respectively.
# 2) Imported string library and used set(string.ascii_uppercase) to import set of all uppercase alphabets.
# 3) Used isupper()/islower() to check condition in the loop.
# 4) split() is used to split up the string.
