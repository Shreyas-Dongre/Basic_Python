# %% [markdown]
#  IPL Dataset Analysis
#
# ## Problem Statement
# We want to know as to what happens during an IPL match which raises several questions in our mind with our limited knowledge about the game called cricket on which it is based. This analysis is done to know as which factors led one of the team to win and how does it matter.

# %% [markdown]
# ## About the Dataset :
# The Indian Premier League (IPL) is a professional T20 cricket league in India contested during April-May of every year by teams representing Indian cities. It is the most-attended cricket league in the world and ranks sixth among all the sports leagues. It has teams with players from around the world and is very competitive and entertaining with a lot of close matches between teams.
#
# The IPL and other cricket related datasets are available at [cricsheet.org](https://cricsheet.org/%c2%a0(data). Feel free to visit the website and explore the data by yourself as exploring new sources of data is one of the interesting activities a data scientist gets to do.

# %% [markdown]
# ### Analysing data with basic python operation

# %% [markdown]
# ## Read the data of the format .yaml type

# %% [markdown]
# # **FOR Reference**
# - YAML acroynym stands for “YAML Ain’t Markup Language,”.
#
# - YAML is a human-readable data serialization standard that can be used in conjunction with all programming languages and is often used to write configuration files.
#
# - YAML vs. JSON
# YAML 1.2 is a superset of JavaScript Object Notation (JSON) but has some built-in advantages. For example, YAML can self-reference, support complex datatypes, embed block literals, support comments, and more. Overall, YAML tends to be more readable than JSON as well

# %%
import yaml

# %%
# using with open command to read the file
with open ('ipl_match.yaml') as f:
  data = yaml.load(f)

# %%
# print data
data
# Out:
# {'info': {'city': 'Bangalore',
#   'competition': 'IPL',
#   'dates': [datetime.date(2008, 4, 18)],
#   'gender': 'male',
#   'match_type': 'T20',
#   'outcome': {'by': {'runs': 140}, 'winner': 'Kolkata Knight Riders'},
#   'overs': 20,
#   'player_of_match': ['BB McCullum'],
#   'teams': ['Royal Challengers Bangalore', 'Kolkata Knight Riders'],
#   'toss': {'decision': 'field', 'winner': 'Royal Challengers Bangalore'},
#   'umpires': ['Asad Rauf', 'RE Koertzen'],
#   'venue': 'M Chinnaswamy Stadium'},
#  'innings': [{'1st innings': {'deliveries': [{0.1: {'batsman': 'SC Ganguly',
#        'bowler': 'P Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'BB McCullum',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {0.2: {'batsman': 'BB McCullum',
#        'bowler': 'P Kumar',
#        'non_striker': 'SC Ganguly',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.3: {'batsman': 'BB McCullum',
#        'bowler': 'P Kumar',
# ...

# %% [markdown]
# Now let's find answers to some prilminary questions such as

# %% [markdown]
# ### Can you guess the data type with which your working on ?

# %%
print("Data type for this data is:",type(data))
# Out:
# Data type for this data is: <class 'dict'>

# %% [markdown]
# ### In which city the match was played and where was it played ?

# %%
city = data['info']['city']
print('The match was played in:',city)
# Out:
# The match was played in: Bangalore

# %%
venue = data['info']['venue']
print('The place where match was played was:',venue)
# Out:
# The place where match was played was: M Chinnaswamy Stadium

# %% [markdown]
# ### Which are all the teams that played in the tournament ? How many teams participated  in total?

# %%
team = data['info']['teams'][0]
team2 = data['info']['teams'][1]
print('The first team was:',team)
print('The second team was:',team2)

print(len(data['info']['teams']),'teams participated in total')
# Out:
# The first team was: Royal Challengers Bangalore
# The second team was: Kolkata Knight Riders
# 2 teams participated in total

# %% [markdown]
# ### Which team won the toss and what was the decision of toss winner ?

# %%
a = data['info']['toss']['winner']
b = data['info']['toss']['decision']
print(a,'won the toss and chose to',b)
# Out:
# Royal Challengers Bangalore won the toss and chose to field

# %% [markdown]
# ### Find the first bowler who played the first ball of the first inning. Also the first batsman who faced first delivery ?

# %%
a = data['innings'][0]['1st innings']['deliveries'][0][0.1]['bowler']
b = data['innings'][0]['1st innings']['deliveries'][0][0.1]['batsman']

print('The first baller who bowled the first ball in the 1st inning was :',a)
print('The first batsman who faced the first ball in the 1st inning was :',b)
# Out:
# The first baller who bowled the first ball in the 1st inning was : P Kumar
# The first batsman who faced the first ball in the 1st inning was : SC Ganguly

# %% [markdown]
# ### How many deliveries were delivered in first inning ?

# %%
## Does this come out to be more than 120 if yes then why ?
a = len(data['innings'][0]['1st innings']['deliveries'])
print(a,'deliveries were delivered in the first inning.')
print('Total balls = 20*6 + (4 extras) extras in the overs 1,3,12,14')
# Out:
# 124 deliveries were delivered in the first inning.
# Total balls = 20*6 + (4 extras) extras in the overs 1,3,12,14

# %% [markdown]
# ### How many deliveries were delivered in second inning ?

# %%
## Does this come out to be less or greater than 120 then what's your thought process behind it ?
b = len(data['innings'][1]['2nd innings']['deliveries'])
print(b,'deliveries were delivered in the second inning.')
print('Total balls = 15*6 + 2 Balls of next over + (9 extras) extras in the overs 0,2,6,6,8,8,9,12,14')
print('The balls delivered are 101 only because the team got all out. The fall of wickets were at (1.1,2.2,4.5,5.2,7.5,8.2,8.8,11.1,13.1,15.2) overs.')
# Out:
# 101 deliveries were delivered in the second inning.
# Total balls = 15*6 + 2 Balls of next over + (9 extras) extras in the overs 0,2,6,6,8,8,9,12,14
# The balls delivered are 101 only because the team got all out. The fall of wickets were at (1.1,2.2,4.5,5.2,7.5,8.2,8.8,11.1,13.1,15.2) overs.

# %% [markdown]
# ### Which team won and how ?

# %%
## see if the guess of the students is right did they infer it correctly
a = data['info']['outcome']['winner']
b = data['info']['outcome']['by']['runs']
print(a,"won the match by",b,"runs.")
# Out:
# Kolkata Knight Riders won the match by 140 runs.
