# %% [markdown]
# # **Python/ML workshop**
# ## **Organized by IET MPSTME**
#
# ## **Instructor**: Radhika Chapaneri
#
# ## Dec 2020

# %% [markdown]
# # **Functions**

# %% [markdown]
# ```
# def name_of_function(arg1, arg2):
#     '''
#     This is where the function's Document String (docstring) goes
#     '''
#     # Do stuff here
#     # Return desired result
# ```

# %% [markdown]
# **1) Prime check**

# %%
def is_prime(num):
    '''
    Naive method of checking for primes
    '''
    for n in range(2,num):
        if num % n == 0:
            print(num, 'is not prime')
            return
    print(num, 'is prime!')

# %%
is_prime(16)
# Out:
# 16 is not prime

# %%
is_prime(17)
# Out:
# 17 is prime!

# %% [markdown]
# **2) ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with the same letter**
#
# ```
# animal_crackers('Levelheaded Llama') --> True
# animal_crackers('Crazy Kangaroo') --> False
#
# ```

# %%
def animal_crackers(text):
  wordlist = text.split()
  return worldlist[0][0] == wordlist[1][0]

# %%
# Check
animal_crackers('Levelheaded Llama')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e2e995af9a1e> in <module>()
#       1 # Check
# ----> 2 animal_crackers('Levelheaded Llama')
#
# <ipython-input-14-c753305a9c6d> in animal_crackers(text)
#       1 def animal_crackers(text):
#       2   wordlist = text.split()
# ----> 3   return worldlist[0][0] == wordlist[1][0]
#
# NameError: name 'worldlist' is not defined

# %%
# Check
animal_crackers('Crazy Kangaroo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4b2ac49f3054> in <module>()
#       1 # Check
# ----> 2 animal_crackers('Crazy Kangaroo')
#
# <ipython-input-5-c753305a9c6d> in animal_crackers(text)
#       1 def animal_crackers(text):
#       2   wordlist = text.split()
# ----> 3   return worldlist[0][0] == wordlist[1][0]
#
# NameError: name 'worldlist' is not defined

# %% [markdown]
# **3) MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 or if one of the integers is 20. If not, return False**
# ```
# makes_twenty(20, 10) --> True
# makes_twenty(12, 8) --> True
# makes_twenty(2, 3) --> False
# ```

# %%
def makes_twenty(n1, n2):
  return (n1 + n2) == 20 or n1 ==20 or n2 == 20

# %%
makes_twenty(20, 10)
# Out:
# True

# %%
makes_twenty(12, 8)
# Out:
# True

# %%
makes_twenty(2, 3)
# Out:
# False

# %% [markdown]
# **4) Given a sentence, return a sentence with the words reversed**
#
# ```
# rev_text('I am home') --> 'home am I'
# rev_text('We are ready') --> 'ready are We'
# ```

# %%
None

# %%
rev_text('I am home')

# %%
rev_text('We are ready')

# %% [markdown]
# **5) Given an integer n, return True if n is within 10 of either 100 or 200**
#
# ```
# within_range(90) --> True
# within_range(104) --> True
# within_range(150) --> False
# within_range(209) --> True
# ```
#
# Hint: use `abs()`

# %%
None

# %%
within_range(90)

# %%
within_range(104)

# %% [markdown]
# # **Lambda Functions**
#
# * Lambda expressions allow us to create "anonymous" functions.
#
# * This means that we can quickly make ad-hoc functions without needing to properly define a function using def.
#
# * **Note**: lambda's body is a single expression, not a block of statements.

# %%
def square(num):
    return num**2

# %%
square(4)
# Out:
# 16

# %%
lambda num: num ** 2
# Out:
# <function __main__.<lambda>>

# %%
square2 = lambda num: num ** 2
square2
# Out:
# <function __main__.<lambda>>

# %%
square2(5)
# Out:
# 25
